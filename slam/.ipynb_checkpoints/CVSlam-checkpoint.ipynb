# %%
import numpy as np
import matplotlib.pyplot as plt
import lies
import cv2 as cv
import math
import random
import scipy
from scipy import optimize
from scipy import linalg

# stuff in this file are not really working:
import slam

# %%
img0 = 'k0.jpg'
img1 = 'k1.jpg'
img2 = 'k2.jpg'

trans01 = np.array([0.15, 0, 0, 0, 0, 0])
f = 3000

# %%
def se3exp(xi):
    return lies.se3exp(xi)
    
def se3log(M):
    return lies.se3log(M)

def imgval(I, p):
    return slam.imgval(I, p)

def slamResiduals(Ii, Ij, p, xi):
    return slam.slamResiduals(Ii, Ij, p, xi)

def getMatches(px0, px1, lowe=0.4):
    return slam.getMatches(px0, px1, lowe)

# %%
px0 = cv.imread(img0, 0)
px1 = cv.imread(img1, 0)
px2 = cv.imread(img2, 0)

# %%
w, h = px0.shape

# %%
good, pts0, pts1 = getMatches(px0, px1, 0.6)

B = np.linalg.norm(trans01)
pts0 = np.array(pts0)
pts1 = np.array(pts1)
disp = np.linalg.norm(pts1 - pts0, axis=1)
depth = B * f / disp
p = np.array([(pts0[:,0] - w/2) * depth, (pts0[:,1] - h/2) * depth, depth, np.ones(depth.shape)])

# %%
#print (pts0[:15,], pts1[:15,], disp[:15], depth[:15])
nn,two = pts0.shape
print(nn)
print(px0.shape)

px0p = cv.cvtColor(px0, cv.COLOR_GRAY2BGR)
px1p = cv.cvtColor(px1, cv.COLOR_GRAY2BGR)
for i in range(nn):
    colour = (random.randint(60, 256), random.randint(0, 200), random.randint(20, 200))
    j = i#random.randint(0, nn-1)
    print(tuple(pts0[j,:].astype(int).tolist()), tuple(pts1[j,:].astype(int).tolist()), disp[j], depth[j])
    px0p = cv.circle(px0p, tuple(pts0[j,:].astype(int).tolist()), 24, colour, -1)
    px1p = cv.circle(px1p, tuple(pts1[j,:].astype(int).tolist()), 24, colour, -1)
    
plt.subplot(121),plt.imshow(px0p)
plt.subplot(122),plt.imshow(px1p)
plt.show()
# Out:
# 187
# (3264, 1840)
# (56, 1064) (378, 837) 394.1276506666196 1.1417620642420774
# (116, 2442) (237, 1616) 834.9244421082523 0.5389709263555793
# (120, 2439) (237, 1616) 830.9964266977757 0.5415185740186823
# (129, 2431) (237, 1616) 821.9727800747933 0.5474633843216237
# (149, 2353) (143, 2784) 430.22428248637357 1.045966065419036
# (153, 284) (378, 837) 597.8519492726065 0.7526947107013789
# (169, 1348) (300, 1788) 459.6389674570644 0.9790292639669095
# (178, 371) (404, 912) 586.2151875280842 0.7676362018144429
# (187, 1336) (314, 1776) 457.9866859615387 0.9825613141028965
# (187, 1336) (314, 1776) 457.9866859615387 0.9825613141028965
# (198, 551) (417, 1068) 561.3750758212572 0.8016030981455272
# (246, 1397) (368, 1829) 449.2754945161484 1.001612608505683
# (275, 2611) (243, 3051) 440.8290763498474 1.0208038084195572
# (283, 2761) (237, 1616) 1146.0192151860767 0.3926635732080063
# (283, 2761) (237, 1616) 1146.0192151860767 0.3926635732080063
# (284, 2778) (237, 1616) 1162.33449918913 0.38715189157159996
# (289, 2824) (237, 1616) 1208.502469363465 0.37236167191037783
# (292, 2846) (237, 1616) 1230.4464805495402 0.3657209046581381
# (293, 2850) (237, 1616) 1235.3649746723615 0.3642648198920705
# (295, 2865) (237, 1616) 1250.3940233954208 0.3598865570214689
# (300, 2888) (237, 1616) 1272.982788225902 0.35350045904952454
# (314, 2377) (237, 1616) 764.8333156862594 0.5883634914572595
# (331, 3038) (237, 1616) 1425.1802646676142 0.3157495308882562
# (332, 3033) (237, 1616) 1419.34328068321 0.31704803631676026
# (334, 3023) (237, 1616) 1410.4081979039333 0.31905656863648685
# (336, 3013) (237, 1616) 1399.699214366213 0.3214976441947644
# (342, 1540) (470, 1967) 446.01762119691097 1.0089287476858024
# (356, 1891) (491, 1875) 135.9136924342963 3.3109246900752107
# (358, 2297) (463, 2733) 447.68201218536916 1.0051777550840506
# (360, 1486) (1750, 2336) 1628.7746943344218 0.27628130616548335
# (365, 1930) (378, 837) 1092.5051142916989 0.4118973852966788
# (368, 1914) (484, 2336) 437.4205090004416 1.0287583474956492
# (374, 1879) (483, 2301) 435.8277985683062 1.032517892337867
# (388, 1500) (517, 1928) 446.96663600523766 1.0067865557525122
# (388, 2732) (1037, 1787) 1146.262167130892 0.3925803475886807
# (390, 2041) (237, 1616) 451.45269550655576 0.996782175583367
# (393, 3195) (237, 1616) 1585.933549225704 0.28374454920869935
# (397, 1541) (518, 1966) 441.7696658231891 1.0186303741826062
# (397, 1541) (518, 1966) 441.7696658231891 1.0186303741826062
# (403, 3085) (237, 1616) 1478.2171836576313 0.30442076101871657
# (404, 3069) (237, 1616) 1461.8784434286856 0.30782313127524563
# (405, 3059) (237, 1616) 1452.682614025116 0.3097717255341364
# (406, 3056) (237, 1616) 1449.3274435550923 0.3104888422565045
# (414, 2963) (237, 1616) 1358.0248100896272 0.33136360739263726
# (414, 2953) (237, 1616) 1348.6679100897336 0.3336625692903594
# (415, 2947) (237, 1616) 1342.5999304036404 0.33517058195043375
# (433, 1578) (237, 1616) 198.77487325454882 2.263867623870826
# (435, 654) (638, 1148) 533.7054307788851 0.8431617406314825
# (502, 518) (686, 1019) 534.303029408933 0.8422186946942968
# (531, 3219) (237, 1616) 1629.3057680852614 0.2761912520133247
# (532, 3208) (237, 1616) 1618.7430717555303 0.2779934678033705
# (533, 3204) (237, 1616) 1614.9243401214653 0.2786508251935528
# (533, 3193) (237, 1616) 1604.076768850087 0.2805352017675507
# (534, 3179) (237, 1616) 1591.0896318868174 0.28282504705053024
# (555, 2561) (493, 3012) 454.7673357674585 0.9895169784799666
# (612, 509) (795, 1005) 528.564792411135 0.8513620401148005
# (612, 509) (795, 1005) 528.564792411135 0.8513620401148005
# (617, 1859) (795, 2281) 457.8663914130576 0.9828194609593849
# (634, 2130) (1279, 1219) 1116.0573310337563 0.40320509304229396
# (650, 647) (843, 1135) 525.2722374170888 0.8566986182494175
# (709, 2016) (237, 1616) 617.7450333865339 0.7284558769061396
# (722, 2478) (1168, 1618) 968.522651340188 0.46462516842256085
# (802, 648) (979, 1112) 496.7729433353841 0.9058464355539458
# (835, 2535) (811, 2998) 463.3563194662491 0.9711748412503912
# (859, 1290) (1053, 1716) 469.0516072892683 0.9593827054567174
# (872, 1761) (1019, 2184) 447.68809739651084 1.0051640921814402
# (873, 2448) (855, 2903) 455.579284523967 0.9877534279685329
# (879, 1374) (1037, 1787) 441.67899400397346 1.0188394877478635
# (886, 1620) (1035, 2041) 446.9619593593867 1.006797089946911
# (888, 1191) (1042, 1619) 454.7062062413428 0.9896500065828332
# (888, 1273) (1045, 1703) 457.1965793140474 0.9842593325504649
# (892, 1418) (1055, 1833) 446.624709271586 1.0075573309276122
# (897, 2413) (1167, 2994) 641.0328435308038 0.7019921124811696
# (899, 1131) (1053, 1562) 457.8852938549356 0.9827788881609424
# (900, 1167) (1056, 1596) 456.3020272549474 0.9861889124340306
# (904, 1219) (1057, 1645) 452.22343635651606 0.9950833234685272
# (921, 638) (1080, 1112) 500.4060478575158 0.899269706924349
# (922, 673) (1080, 1137) 490.1861259592494 0.9180186385720142
# (923, 1062) (1073, 1498) 461.64296621862985 0.9747792838392
# (927, 842) (1081, 1293) 476.2864140847711 0.9448096495985868
# (928, 767) (1081, 1227) 484.3549960047965 0.929070627353545
# (929, 573) (1087, 1049) 501.55026199758896 0.8972181535858977
# (935, 1131) (1086, 1560) 455.06478118170816 0.9888701974067166
# (942, 2125) (931, 2559) 433.66648005953044 1.0376637824030748
# (958, 2139) (950, 2575) 436.0298460348181 1.032039444300027
# (959, 1441) (1124, 1859) 449.75864150963804 1.0005366400288649
# (959, 2179) (951, 2618) 438.5657899284702 1.0260718239637312
# (959, 2179) (951, 2618) 438.5657899284702 1.0260718239637312
# (970, 1749) (1164, 2169) 462.9489633541411 0.9720293933475437
# (973, 1143) (1121, 1570) 452.32824326419797 0.9948527572645114
# (978, 1033) (1125, 1466) 456.8658315035124 0.9849718866457632
# (979, 839) (1127, 1289) 473.34408960484006 0.9506826215484632
# (981, 1249) (1135, 1672) 450.13916853786253 0.9996908321968191
# (983, 1165) (1133, 1591) 451.7150691591513 0.9962032057900042
# (991, 832) (1139, 1281) 473.28552043461036 0.9508002686977881
# (994, 1223) (1146, 1646) 449.74355737687694 1.0005701974356649
# (995, 812) (1143, 1262) 474.182923597279 0.9490008551682527
# (998, 1158) (1148, 1584) 452.5028411530047 0.9944688940590355
# (999, 815) (1143, 1262) 470.19768102116194 0.957044277680619
# (1007, 1525) (1185, 1938) 449.4287618298018 1.0012710316266198
# (1007, 1201) (1157, 1625) 450.0310308873993 0.9999310472272587
# (1014, 1166) (1165, 1591) 451.1318477211422 0.9974910932871185
# (1018, 1194) (1168, 1618) 449.64924268944554 1.0007800687230262
# (1018, 1194) (1168, 1618) 449.64924268944554 1.0007800687230262
# (1022, 2587) (1024, 3059) 472.0484467755948 0.9532919832144341
# (1029, 1186) (1180, 1610) 450.20887766563845 0.9995360427659234
# (1033, 1430) (1201, 1848) 450.1516646502872 0.9996630809964792
# (1042, 1177) (1193, 1601) 449.79245850861594 1.000461416120831
# (1042, 1203) (1195, 1626) 450.17427779582215 0.9996128659401078
# (1047, 1471) (1223, 1887) 451.0471205957151 0.9976784673975256
# (1053, 1415) (1222, 1833) 450.8578315067592 0.9980973347986607
# (1060, 1193) (1214, 1615) 449.6840231277405 1.0007026642175583
# (1066, 1061) (1222, 1488) 454.9139201803371 0.9891981318611022
# (1066, 844) (1215, 1288) 468.5247605729017 0.9604615121082394
# (1069, 2562) (1075, 3036) 473.95649153555036 0.9494542390211076
# (1080, 1228) (1236, 1650) 449.62005427368723 1.0008450373214035
# (1081, 1003) (1230, 1435) 456.6888453465364 0.9853536047252021
# (1081, 1160) (1245, 1586) 456.3192498713559 0.9861516912268387
# (1089, 497) (1236, 972) 496.63056754233816 0.9061061267873672
# (1093, 1601) (1250, 2018) 446.05885251704154 1.0088354876508316
# (1107, 1211) (1265, 1632) 449.45265091936204 1.0012178125538216
# (1110, 850) (1258, 1294) 468.2467491420492 0.961031765462372
# (1113, 1230) (1269, 1649) 447.46819106446446 1.0056580757830242
# (1120, 1209) (1207, 1318) 139.75081320811364 3.2200170408301707
# (1121, 1244) (1277, 1664) 447.8668777694255 1.0047628488206102
# (1125, 1052) (1277, 1467) 441.2043241338217 1.0199356066680583
# (1126, 1618) (1288, 2035) 447.0442540746515 1.0066117524124467
# (1127, 1207) (1282, 1627) 447.48197406024264 1.0056271002760402
# (1135, 1300) (1302, 1719) 451.1700774183422 0.997406571319983
# (1140, 1269) (1298, 1687) 447.15602525153497 1.0063601396109227
# (1146, 1635) (1370, 2068) 487.73741806838603 0.9226275929006234
# (1150, 765) (1306, 1213) 473.8272495247221 0.9497132139432203
# (1152, 1217) (1310, 1637) 448.50748677172044 1.0033277331422545
# (1152, 1217) (1310, 1637) 448.50748677172044 1.0033277331422545
# (1152, 730) (1306, 1182) 477.4615457686844 0.9424842775045413
# (1169, 1554) (1348, 1969) 452.2147941770232 0.9951023402915116
# (1196, 2574) (1209, 3054) 480.04163852738947 0.9374186818052963
# (1197, 1175) (1370, 1595) 453.54803449965027 0.9921771582505822
# (1206, 815) (1371, 1254) 469.38832245629004 0.9586944933891159
# (1214, 626) (1385, 1077) 483.10482153308806 0.9314748682738603
# (1238, 1627) (1431, 2049) 463.593411243268 0.9706781612646023
# (1240, 1213) (1416, 1630) 452.48126580932205 0.9945163126148793
# (1240, 1233) (1419, 1651) 454.94179156070953 0.9891375300040993
# (1246, 1839) (1434, 2269) 470.0341560662003 0.9573772335315592
# (1249, 1197) (1426, 1615) 453.64747050573146 0.9919596807149278
# (1250, 1238) (1426, 1654) 451.29744944646336 0.9971250680719451
# (1254, 868) (1431, 1301) 468.8294474329817 0.9598373192296686
# (1257, 970) (1408, 1372) 429.7222340085753 1.0471880772895266
# (1264, 691) (1442, 1139) 482.06939009419466 0.9334755727014146
# (1265, 1186) (1443, 1603) 453.6841089185577 0.9918795724907812
# (1275, 1207) (1454, 1623) 452.93115488269507 0.9935284759039059
# (1300, 1311) (1482, 1722) 449.8631842499211 1.0003041274655693
# (1311, 1242) (1509, 1655) 458.3285451848813 0.9818284388516065
# (1336, 1398) (1522, 1811) 453.3231459490029 0.9926693662595893
# (1336, 1397) (1522, 1811) 453.6495428137064 0.9919551493625001
# (1341, 1805) (1542, 2228) 467.6360253542439 0.9622868547373264
# (1348, 1370) (1536, 1783) 454.1543185843406 0.9908526278087806
# (1348, 1370) (1536, 1783) 454.1543185843406 0.9908526278087806
# (1365, 782) (1541, 1217) 469.0533515922819 0.9593791377300641
# (1382, 1795) (1591, 2218) 471.6691224104008 0.9540586369112659
# (1392, 1844) (1604, 2271) 476.9612295538793 0.9434729116681093
# (1393, 1779) (1604, 2202) 472.6432542574391 0.952092293598872
# (1393, 1868) (1606, 2297) 478.5780106309621 0.9402855751912116
# (1396, 1750) (1611, 2171) 473.4189994018779 0.9505321936139748
# (1411, 1861) (1625, 2288) 477.25633712928544 0.9428895228647286
# (1418, 1792) (1631, 2216) 474.23439107185186 0.9488978624745499
# (1432, 1801) (215, 2790) 1568.6359099575352 0.2868734530068115
# (1453, 1380) (1669, 1791) 463.9684890441516 0.9698934531676302
# (1453, 1380) (1669, 1791) 463.9684890441516 0.9698934531676302
# (1458, 1307) (1672, 1719) 463.8199314921034 0.9702041017348157
# (1468, 914) (1650, 1337) 459.83874917185426 0.9786039145470595
# (1483, 775) (1670, 1205) 468.56387473058146 0.96038133596779
# (1483, 1257) (1699, 1665) 461.53310412648835 0.9750113176641657
# (1487, 819) (1675, 1243) 463.38133230269267 0.9711224182549684
# (1494, 1318) (1709, 1722) 457.3056370391235 0.984024607511019
# (1501, 777) (1688, 1205) 467.3088731408533 0.9629605296716971
# (1513, 803) (1699, 1228) 463.9220659310329 0.9699905071273274
# (1513, 803) (1699, 1228) 463.9220659310329 0.9699905071273274
# (1516, 841) (1701, 1266) 463.5765326000855 0.970713503282968
# (1522, 820) (1710, 1245) 464.47907137662395 0.9688272900354566
# (1535, 1306) (1750, 1714) 461.14543801747715 0.9758309698012132
# (1538, 952) (1726, 1369) 457.3024469063627 0.9840314720470805
# (1543, 967) (1729, 1384) 456.6117837903406 0.9855199010952891
# (1548, 810) (1736, 1234) 463.35822710845105 0.9711708429311551
# (1568, 1307) (1785, 1715) 462.2576855790655 0.9734830031788213
# (1571, 1371) (1789, 1781) 464.33208413369243 0.9691339784102322
# (1573, 1285) (1787, 1693) 461.22719151505544 0.9756580016928837

# %%
xi0 = np.array([.0,.00,0.0,0.0,0.0,0.0])

xi = scipy.optimize.fmin(lambda xi: slamResiduals(px0, px2, p, xi), xi0)
#xi = slam.slamStepIterate(px0, px2, p, xi0, 100)

print(xi)
# Out:
# bad:  56 / 187
# bad:  56 / 187
# bad:  56 / 187
# bad:  56 / 187
# bad:  58 / 187
# bad:  56 / 187
# bad:  56 / 187
# bad:  65 / 187
# bad:  62 / 187
# bad:  78 / 187
# bad:  56 / 187
# bad:  69 / 187
# bad:  56 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  59 / 187
# bad:  61 / 187
# bad:  57 / 187
# bad:  56 / 187
# bad:  61 / 187
# bad:  61 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  59 / 187
# bad:  59 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# bad:  57 / 187
# Optimization terminated successfully.
#          Current function value: 3369.992308
#          Iterations: 79
#          Function evaluations: 188
# [ 1.00935565e-04 -1.45877534e-04  1.19830348e-04 -5.27145608e-05
#   4.83438638e-05  1.22892394e-04]

# %%
pts0 = np.int32(pts0)
pts1 = np.int32(pts1)
F, mask = cv.findFundamentalMat(pts1,pts0,cv.FM_LMEDS)
# We select only inlier points
pts0 = pts0[mask.ravel()==1]
pts1 = pts1[mask.ravel()==1]

# %%
nn,two = pts0.shape
print(nn)
print(px0.shape)

px0p = cv.cvtColor(px0, cv.COLOR_GRAY2BGR)
px1p = cv.cvtColor(px1, cv.COLOR_GRAY2BGR)
for i in range(nn):
    colour = (random.randint(60, 256), random.randint(0, 200), random.randint(20, 200))
    j = i#random.randint(0, nn-1)
    px0p = cv.circle(px0p, tuple(pts0[j,:].astype(int).tolist()), 24, colour, -1)
    px1p = cv.circle(px1p, tuple(pts1[j,:].astype(int).tolist()), 24, colour, -1)
    
plt.subplot(121),plt.imshow(px0p)
plt.subplot(122),plt.imshow(px1p)
plt.show()
# Out:
# 136
# (3264, 1840)

# %%
lowe = 0.8

sift = cv.xfeatures2d.SIFT_create()
kp0, des0 = sift.detectAndCompute(px0, None)
kp1, des1 = sift.detectAndCompute(px1, None)
kp2, des2 = sift.detectAndCompute(px2, None)

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)

flann = cv.FlannBasedMatcher(index_params, search_params)
matches01 = flann.knnMatch(des1, des0, k=2)
matches02 = flann.knnMatch(des2, des0, k=2)

good01 = {}

# ratio test as per Lowe's paper
for i, (m, n) in enumerate(matches01):
    if m.distance < lowe * n.distance:
        good01[m.trainIdx] = m
        
pts0 = []
pts1 = []
pts2 = []
        
for i, (m, n) in enumerate(matches02):
    if m.distance < lowe * n.distance:
        if m.trainIdx in good01:
            pts0.append(kp0[m.trainIdx].pt)
            pts1.append(kp1[good01[m.trainIdx].queryIdx].pt)
            pts2.append(kp2[m.queryIdx].pt)
        
pts0 = np.int32(pts0)
pts1 = np.int32(pts1)
pts2 = np.int32(pts2)

print(pts0.shape)
# Out:
# (48, 2)

# %%
# we should already know this matrix?
F01, mask = cv.findFundamentalMat(pts1,pts0,cv.FM_LMEDS)
# We select only inlier points
pts0 = pts0[mask.ravel()==1]
pts1 = pts1[mask.ravel()==1]
pts2 = pts2[mask.ravel()==1]


F02, mask = cv.findFundamentalMat(pts2,pts0,cv.FM_LMEDS)
pts0 = pts0[mask.ravel()==1]
pts1 = pts1[mask.ravel()==1]
pts2 = pts2[mask.ravel()==1]

# %%
nn,two = pts0.shape
print(nn)
print(px0.shape)

px0p = cv.cvtColor(px0, cv.COLOR_GRAY2BGR)
px1p = cv.cvtColor(px1, cv.COLOR_GRAY2BGR)
px2p = cv.cvtColor(px2, cv.COLOR_GRAY2BGR)
for i in range(nn):
    colour = (random.randint(60, 256), random.randint(0, 200), random.randint(20, 200))
    j = i#random.randint(0, nn-1)
    px0p = cv.circle(px0p, tuple(pts0[j,:].astype(int).tolist()), 24, colour, -1)
    px1p = cv.circle(px1p, tuple(pts1[j,:].astype(int).tolist()), 24, colour, -1)
    px2p = cv.circle(px2p, tuple(pts2[j,:].astype(int).tolist()), 24, colour, -1)
    
plt.subplot(131),plt.imshow(px0p)
plt.subplot(132),plt.imshow(px1p)
plt.subplot(133),plt.imshow(px2p)
plt.show()
# Out:
# 32
# (3264, 1840)

# %%
# TODO calibrate camera
K0 = np.array([[3000, 0, 920], [0, 3000, 1632], [0, 0, 1]])
K1 = np.array([[3000, 0, 920], [0, 3000, 1632], [0, 0, 1]])

# calculate essential matrix
E = K0.transpose() @ F @ K1
print(E)
# Out:
# [[ 0.04838848 -2.48533417  0.75933007]
#  [ 3.08214856  0.7869844   4.24528328]
#  [-0.40914082 -4.47120266  0.64747899]]

# %%
# get null space of essential matrix
U,s,Vt = scipy.linalg.svd(E)
nullmask = (s <= 1e-8)
t = scipy.compress(nullmask, Vt, axis=0).transpose()

# finding rotation matrix
W = np.array([[0, -1, 0], [1, 0, 0], [0, 1, 1]])
Wt = W.transpose()

Ra = U @ Wt @ Vt
Rb = U @ W @ Vt

print(Ra)
# Out:
# [[ 0.61928852  0.06909407  0.15951715]
#  [-0.42544409  1.06762188  0.13459235]
#  [-0.49146889  0.2642787   1.39138164]]
