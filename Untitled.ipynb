# %%
from frame import frame as frame_
from camera import camera as camera_
from video_process import video_process
import numpy as np

VIDEO_PATH_L = '/home/zarandy/Downloads/left.mp4'
VIDEO_PATH_R = '/home/zarandy/Downloads/right.mp4'
FRAME_DIR_PATH = 'data/image_files'
STEP = 4

# images_cal = video_process.capture_frames_from_video(VIDEO_PATH_C, 5)

imagesL = video_process.capture_frames_from_video(VIDEO_PATH_L, STEP)
imagesR = video_process.capture_frames_from_video(VIDEO_PATH_R, STEP)

R = [[1, 0, 0], [0, 1, 0], [0, 0, 1]]
T = [[10], [10], [10]]
camera = camera_.Camera(86500, 86500, 0.035, 3264 / 2, 2448 / 2, R, T)

# K_sum = None
#
# num = 0
#
# for image_cal in images_cal:
#     updated = camera.calibrate_by_images_and_grid_length(image_cal, 0.024)
#     if updated:
#         num += 1
#         print(camera.K)
#         K_sum = camera.K if num == 1 else K_sum + camera.K
#
# print('avr K')
# avrK = K_sum / num
# print(avrK)

camera.K = np.asmatrix([[1.12265949e+03, 0.00000000e+00, 3.07322388e+02, 0.00000000e+00],
                        [0.00000000e+00, 1.11948374e+03, 5.50850887e+02, 0.00000000e+00],
                        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

camera.update_M_M_pinv_by_K_RT()

print(camera.K)
print(type(camera.K))
print(camera.M)

frames = frame_.generate_raw_frame_chain_from_images(imagesL, imagesR, camera)

for i in range(0, len(frames)):
    frame = frames[i]
    frame.generate_set_kp_des()

print('generate kp and des done')

for i in range(1, len(frames)):
    print('progress check for motion; ', i)
    frame = frames[i]
    frame.generate_set_motion_info()
# Out:
# [[1.12265949e+03 0.00000000e+00 3.07322388e+02 0.00000000e+00]
#  [0.00000000e+00 1.11948374e+03 5.50850887e+02 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00]]
# <class 'numpy.matrixlib.defmatrix.matrix'>
# [[1.12265949e+03 0.00000000e+00 3.07322388e+02 1.42998188e+04]
#  [0.00000000e+00 1.11948374e+03 5.50850887e+02 1.67033463e+04]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00 1.00000000e+01]]
# Warning: len(imageL_list) != len(imageR_list)
# generate kp and des done
# progress check for motion;  1
#
# 94
# 57
# 38
# Optimization terminated successfully.
#          Current function value: 307.899598
#          Iterations: 233
#          Function evaluations: 363
# [ 0.00396811  0.03842484  0.00265858 -0.02409399  0.00586639 -0.04112664]
# 38
# (1080, 1920, 3)
# progress check for motion;  2
#
# 118
# 83
# 58
# Optimization terminated successfully.
#          Current function value: 438.000186
#          Iterations: 350
#          Function evaluations: 541
# [ 0.04381269  0.0017085   0.03486031  0.00082645 -0.00124004 -0.00928192]
# 58
# (1080, 1920, 3)
# progress check for motion;  3
#
# 97
# 61
# 45
# Optimization terminated successfully.
#          Current function value: 470.552624
#          Iterations: 346
#          Function evaluations: 532
# [ 0.05292526  0.0597462   0.04436629  0.0416678  -0.00893817  0.02065297]
# 45
# (1080, 1920, 3)
# progress check for motion;  4
#
# 110
# 74
# 43
# Optimization terminated successfully.
#          Current function value: 141.809628
#          Iterations: 300
#          Function evaluations: 466
# [-0.01856274  0.00493234 -0.00378837  0.01095066  0.0003929   0.01124875]
# 43
# (1080, 1920, 3)
# progress check for motion;  5
#
# 95
# 62
# 36
# Optimization terminated successfully.
#          Current function value: 609.698070
#          Iterations: 729
#          Function evaluations: 1136
# [-0.19105308 -0.04832712 -0.17076835 -0.07863441  0.01981311 -0.09927807]
# 36
# (1080, 1920, 3)
# progress check for motion;  6
#
# 94
# 65
# 44
# Optimization terminated successfully.
#          Current function value: 376.924867
#          Iterations: 544
#          Function evaluations: 830
# [ 0.08053744 -0.05142093  0.11058492 -0.01318864  0.00334217 -0.00606209]
# 44
# (1080, 1920, 3)
# progress check for motion;  7
#
# 55
# 30
# 17
# Optimization terminated successfully.
#          Current function value: 881.391100
#          Iterations: 572
#          Function evaluations: 873
# [ 0.73520722 -0.01941023  0.36638602  0.05555851 -0.15547107 -0.12789754]
# 17
# (1080, 1920, 3)
# progress check for motion;  8
#
# 35
# 18
# 11
# FATAL:  ('Not enough matches',)
# progress check for motion;  9
#
# 34
# 18
# 10
# FATAL:  ('Not enough matches',)
# progress check for motion;  10
#
# 60
# 40
# 28
# Optimization terminated successfully.
#          Current function value: 333.803078
#          Iterations: 382
#          Function evaluations: 593
# [-0.01431364 -0.0005867  -0.01465134 -0.00122482 -0.00203338 -0.02175544]
# 28
# (1080, 1920, 3)
# progress check for motion;  11
#
# 65
# 43
# 24
# Optimization terminated successfully.
#          Current function value: 686.849050
#          Iterations: 383
#          Function evaluations: 594
# [ 0.1751156  -0.03753615  0.14637202 -0.12309133 -0.01973341 -0.16431965]
# 24
# (1080, 1920, 3)
# progress check for motion;  12
#
# 59
# 30
# 17
# Optimization terminated successfully.
#          Current function value: 580.224988
#          Iterations: 344
#          Function evaluations: 530
# [-0.04309581  0.00586397 -0.05252005 -0.02937855 -0.00247366 -0.05297483]
# 17
# (1080, 1920, 3)
# progress check for motion;  13
#
# 76
# 57
# 36
# Optimization terminated successfully.
#          Current function value: 637.703493
#          Iterations: 327
#          Function evaluations: 509
# [-0.02150083 -0.00562537 -0.0081064  -0.01240113  0.00238226 -0.01948016]
# 36
# (1080, 1920, 3)
# progress check for motion;  14
#
# 40
# 33
# 20
# Optimization terminated successfully.
#          Current function value: 1307.057856
#          Iterations: 484
#          Function evaluations: 746
# [-0.03252461  0.03906736 -0.08212713  0.00990884 -0.03747985 -0.11419512]
# 20
# (1080, 1920, 3)
# progress check for motion;  15
#
# 85
# 54
# 34
# Optimization terminated successfully.
#          Current function value: 1310.425041
#          Iterations: 632
#          Function evaluations: 977
# [ 0.0604956   0.0448473   0.07850164  0.0865075  -0.01455561 -0.02408911]
# 34
# (1080, 1920, 3)
# progress check for motion;  16
#
# 16
# 9
# FATAL:  ('Not enough matches',)
# progress check for motion;  17
#
# 59
# 37
# 21
# Optimization terminated successfully.
#          Current function value: 1203.319870
#          Iterations: 567
#          Function evaluations: 871
# [-0.06407789 -0.05689019  0.06610942 -0.06254903  0.13550946 -0.02778248]
# 21
# (1080, 1920, 3)
# progress check for motion;  18
#
# 51
# 35
# 24
# Optimization terminated successfully.
#          Current function value: 963.087023
#          Iterations: 402
#          Function evaluations: 629
# [ 0.13134038  0.02873306  0.11481395  0.05778731 -0.01770419 -0.05167483]
# 24
# (1080, 1920, 3)
# progress check for motion;  19
#
# 59
# 39
# 22
# Optimization terminated successfully.
#          Current function value: 680.142208
#          Iterations: 458
#          Function evaluations: 709
# [-0.04007838  0.01097835 -0.04444777 -0.01909103 -0.01227757 -0.11609694]
# 22
# (1080, 1920, 3)
# progress check for motion;  20
#
# 129
# 88
# 58
# Optimization terminated successfully.
#          Current function value: 695.676478
#          Iterations: 735
#          Function evaluations: 1143
# [ 0.03535265  0.2638836  -0.00611004  0.02384658 -0.01448089 -0.06966379]
# 58
# (1080, 1920, 3)
# progress check for motion;  21
#
# 197
# 122
# 88
# Optimization terminated successfully.
#          Current function value: 895.598908
#          Iterations: 415
#          Function evaluations: 632
# [ 0.00688521 -0.13721658  0.11035751 -0.1268827   0.0078055  -0.09929621]
# 88
# (1080, 1920, 3)
# progress check for motion;  22
#
# 211
# 152
# 109
# Optimization terminated successfully.
#          Current function value: 1088.509666
#          Iterations: 278
#          Function evaluations: 430
# [ 0.01529906 -0.19790691  0.117226   -0.10677946  0.01556843 -0.0332478 ]
# 109
# (1080, 1920, 3)
# progress check for motion;  23
#
# 152
# 106
# 80
# Optimization terminated successfully.
#          Current function value: 618.080281
#          Iterations: 561
#          Function evaluations: 854
# [ 0.07834467 -0.09204498  0.07531492  0.0051101  -0.00512409  0.03106045]
# 80
# (1080, 1920, 3)
# progress check for motion;  24
#
# 178
# 128
# 81
# Optimization terminated successfully.
#          Current function value: 1266.587018
#          Iterations: 486
#          Function evaluations: 745
# [ 0.41945141 -0.8496273   0.54080937 -0.05568345  0.01620922  0.05540953]
# 81
# (1080, 1920, 3)
# progress check for motion;  25
#
# 19
# 10
# FATAL:  ('Not enough matches',)
# progress check for motion;  26
#
# 30
# 17
# 9
# FATAL:  ('Not enough matches',)
# progress check for motion;  27
#
# 36
# 25
# 25
# Optimization terminated successfully.
#          Current function value: 658.548281
#          Iterations: 634
#          Function evaluations: 968
# [-0.07952817  0.05800181 -0.01285144  0.26361113  0.08332307  0.13984223]
# 25
# (1080, 1920, 3)
# progress check for motion;  28
#
# 32
# 20
# 13
# FATAL:  ('Not enough matches',)
# progress check for motion;  29
#
# 20
# 11
# FATAL:  ('Not enough matches',)
# progress check for motion;  30
#
# 21
# 14
# FATAL:  ('Not enough matches',)
# progress check for motion;  31
#
# 84
# 53
# 53
# Optimization terminated successfully.
#          Current function value: 2193.746329
#          Iterations: 494
#          Function evaluations: 774
# [ 0.31013988 -0.2379034   0.13194371 -0.16552178 -0.2252801   0.36191507]
# 53
# (1080, 1920, 3)
# progress check for motion;  32
#
# 48
# 28
# 18
# Optimization terminated successfully.
#          Current function value: 764.913905
#          Iterations: 533
#          Function evaluations: 803
# [ 0.19835845  0.01196591  0.13866275  0.06982269 -0.05310992 -0.08202609]
# 18
# (1080, 1920, 3)
# progress check for motion;  33
#
# 93
# 56
# 43
# Optimization terminated successfully.
#          Current function value: 1863.137513
#          Iterations: 739
#          Function evaluations: 1131
# [ 1.85808602 -0.13337243  2.17669785 -0.38628759  0.0806311  -0.0664464 ]
# 43
# (1080, 1920, 3)
# progress check for motion;  34
#
# 76
# 47
# 36
# Optimization terminated successfully.
#          Current function value: 412.541478
#          Iterations: 496
#          Function evaluations: 777
# [ 0.05926827 -0.07515362  0.01991473 -0.03548534 -0.02048238  0.04811181]
# 36
# (1080, 1920, 3)
# progress check for motion;  35
#
# 183
# 127
# 87
# Optimization terminated successfully.
#          Current function value: 582.062339
#          Iterations: 395
#          Function evaluations: 626
# [-0.02820242 -0.02254872  0.00441972 -0.02543311  0.00076519 -0.0055735 ]
# 87
# (1080, 1920, 3)
# progress check for motion;  36
#
# 133
# 81
# 62
# Optimization terminated successfully.
#          Current function value: 628.132188
#          Iterations: 641
#          Function evaluations: 970
# [ 0.12392183 -0.12737115  0.15668039 -0.0019656   0.00035494 -0.01181523]
# 62
# (1080, 1920, 3)
# progress check for motion;  37
#
# 158
# 118
# 77
# Optimization terminated successfully.
#          Current function value: 934.088227
#          Iterations: 407
#          Function evaluations: 618
# [3.20775827e-05 4.64392026e-02 1.69584302e-02 2.91265281e-02
#  7.77693794e-03 6.11357337e-03]
# 77
# (1080, 1920, 3)
# progress check for motion;  38
#
# 68
# 49
# 40
# Optimization terminated successfully.
#          Current function value: 779.051623
#          Iterations: 453
#          Function evaluations: 717
# [ 0.02595401  0.15060046  0.34125063 -0.03933729  0.07342314 -0.15114252]
# 40
# (1080, 1920, 3)
# progress check for motion;  39
#
# 74
# 41
# 29
# Optimization terminated successfully.
#          Current function value: 870.558078
#          Iterations: 588
#          Function evaluations: 910
# [0.07076686 0.31643107 0.15059935 0.11671138 0.01787531 0.0078278 ]
# 29
# (1080, 1920, 3)
# progress check for motion;  40
#
# 108
# 74
# 45
# Optimization terminated successfully.
#          Current function value: 494.324337
#          Iterations: 349
#          Function evaluations: 544
# [ 0.0086974  -0.00586472  0.00624556 -0.01672849  0.0040263  -0.01560687]
# 45
# (1080, 1920, 3)
# progress check for motion;  41
#
# 195
# 130
# 77
# Warning: Maximum number of function evaluations has been exceeded.
# [-0.02515816  0.23099708 -0.03617384  0.05413798 -0.00955794 -0.05934062]
# 77
# (1080, 1920, 3)
# progress check for motion;  42
#
# 170
# 112
# 81
# Warning: Maximum number of function evaluations has been exceeded.
# [ 0.82784265  0.5613496   0.73461549  0.02217058 -0.01449799 -0.04253789]
# 81
# (1080, 1920, 3)
# progress check for motion;  43
#
# 57
# 42
# 25
# Optimization terminated successfully.
#          Current function value: 762.885632
#          Iterations: 669
#          Function evaluations: 1042
# [ 0.86088178  0.2994239   0.76285847  0.29800889 -0.05582482  0.09987918]
# 25
# (1080, 1920, 3)
# progress check for motion;  44
#
# 59
# 47
# 28
# Optimization terminated successfully.
#          Current function value: 854.034679
#          Iterations: 372
#          Function evaluations: 570
# [ 0.11495525  0.02984997  0.15173536  0.04006185  0.00994562 -0.03125701]
# 28
# (1080, 1920, 3)
# progress check for motion;  45
#
# 45
# 30
# 19
# Optimization terminated successfully.
#          Current function value: 696.152668
#          Iterations: 678
#          Function evaluations: 1047
# [ 0.76152479 -0.21449597  0.77361526 -0.01765206  0.00121324 -0.03971792]
# 19
# (1080, 1920, 3)
# progress check for motion;  46
#
# 48
# 28
# 15
# Optimization terminated successfully.
#          Current function value: 622.007427
#          Iterations: 606
#          Function evaluations: 913
# [ 0.36020356 -0.27001773  0.32609155 -0.08139646 -0.00254659  0.01051629]
# 15
# (1080, 1920, 3)
# progress check for motion;  47
#
# 63
# 46
# 27
# Optimization terminated successfully.
#          Current function value: 425.278750
#          Iterations: 249
#          Function evaluations: 382
# [ 0.0129703  -0.01083299  0.00850992 -0.01924147 -0.00128757  0.00444282]
# 27
# (1080, 1920, 3)
# progress check for motion;  48
#
# 54
# 36
# 20
# Optimization terminated successfully.
#          Current function value: 217.366354
#          Iterations: 352
#          Function evaluations: 541
# [-0.02094713 -0.00383774 -0.01337484  0.00566997  0.00411719  0.00192897]
# 20
# (1080, 1920, 3)
# progress check for motion;  49
#
# 43
# 22
# 13
# FATAL:  ('Not enough matches',)
# progress check for motion;  50
#
# 58
# 36
# 24
# Optimization terminated successfully.
#          Current function value: 588.404691
#          Iterations: 483
#          Function evaluations: 731
# [ 0.03923168  0.02403107  0.08252056 -0.03262655  0.02080663 -0.03413317]
# 24
# (1080, 1920, 3)
# progress check for motion;  51
#
# 100
# 54
# 34
# Optimization terminated successfully.
#          Current function value: 1072.285244
#          Iterations: 482
#          Function evaluations: 758
# [-0.07465925  0.08997348 -0.09540705  0.03577997 -0.02403311 -0.02023691]
# 34
# (1080, 1920, 3)
# progress check for motion;  52
#
# 72
# 52
# 38
# Optimization terminated successfully.
#          Current function value: 979.220120
#          Iterations: 534
#          Function evaluations: 801
# [ 0.07287698 -0.00158029  0.08327803  0.03514648 -0.01093496  0.09065743]
# 38
# (1080, 1920, 3)
# progress check for motion;  53
#
# 70
# 60
# 35
# Optimization terminated successfully.
#          Current function value: 530.229399
#          Iterations: 300
#          Function evaluations: 457
# [ 0.02887834 -0.01408617  0.03091596 -0.01954417 -0.00014065  0.00440332]
# 35
# (1080, 1920, 3)
# progress check for motion;  54
#
# 61
# 37
# 22
# Optimization terminated successfully.
#          Current function value: 795.354472
#          Iterations: 590
#          Function evaluations: 917
# [-0.00729871  0.09680848  0.13510766  0.02686878  0.02423602  0.03187832]
# 22
# (1080, 1920, 3)
# progress check for motion;  55
#
# 95
# 66
# 36
# Optimization terminated successfully.
#          Current function value: 507.514184
#          Iterations: 544
#          Function evaluations: 819
# [ 0.43202897 -0.01288269  0.53559523  0.00154006  0.00849615 -0.00566903]
# 36
# (1080, 1920, 3)
# progress check for motion;  56
#
# 114
# 78
# 48
# Optimization terminated successfully.
#          Current function value: 1213.930554
#          Iterations: 752
#          Function evaluations: 1142
# [ 0.83603625  0.13077925  0.81337567 -0.03640902 -0.00957273 -0.00880457]
# 48
# (1080, 1920, 3)
# progress check for motion;  57
#
# 94
# 64
# 37
# Optimization terminated successfully.
#          Current function value: 421.638057
#          Iterations: 424
#          Function evaluations: 645
# [ 0.00136937  0.04672173  0.0048764   0.00799352 -0.00282182  0.01010299]
# 37
# (1080, 1920, 3)
# progress check for motion;  58
#
# 67
# 36
# 26
# Optimization terminated successfully.
#          Current function value: 492.707520
#          Iterations: 296
#          Function evaluations: 454
# [-0.00547722 -0.01297815 -0.00627305 -0.02116023 -0.00158718  0.02487409]
# 26
# (1080, 1920, 3)
# progress check for motion;  59
#
# 72
# 54
# 31
# Optimization terminated successfully.
#          Current function value: 642.627922
#          Iterations: 590
#          Function evaluations: 922
# [ 0.03446098 -0.08510973  0.01329181 -0.04901582 -0.00803763  0.04287653]
# 31
# (1080, 1920, 3)
# progress check for motion;  60
#
# 77
# 54
# 31
# Optimization terminated successfully.
#          Current function value: 475.139503
#          Iterations: 223
#          Function evaluations: 348
# [-0.03182059 -0.00915049  0.01057313 -0.01032908  0.00395861  0.02769677]
# 31
# (1080, 1920, 3)
# progress check for motion;  61
#
# 66
# 41
# 23
# Optimization terminated successfully.
#          Current function value: 217.264252
#          Iterations: 402
#          Function evaluations: 601
# [-0.06504825 -0.00724868 -0.04001361  0.00384924  0.00693682  0.00722225]
# 23
# (1080, 1920, 3)
# progress check for motion;  62
#
# 65
# 41
# 24
# Optimization terminated successfully.
#          Current function value: 1076.235919
#          Iterations: 352
#          Function evaluations: 545
# [ 0.03302937  0.01406689 -0.00441801  0.03047795 -0.06746519 -0.02330159]
# 24
# (1080, 1920, 3)
# progress check for motion;  63
#
# 85
# 75
# 75
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 180
#          Function evaluations: 282
# [0. 0. 0. 0. 0. 0.]
# 75
# (1080, 1920, 3)
